# %% [markdown]
# # Prepare audio data for image recognition
#
# The data is pretty good, but there's a few samples that aren't exactly 1 second long and some samples that are either truncated or don't contain very much of the word.
#
# The code in the notebook attempts to filter out the broken audio so that we are only using good audio.
#
# We then generate spectrograms of each word. We mix in background noise with the words to make it a more realistic audio sample.

# %% [markdown]
# ## Download data set
# Download from: https://storage.cloud.google.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz - approx 2.3 GB
#
# And then run
# ```
# tar -xzf data_speech_commands_v0.02.tar.gz -C speech_data
# ```

# %%
import tensorflow as tf
import numpy as np
from tensorflow.io import gfile
import tensorflow_io as tfio
from tensorflow.python.ops import gen_audio_ops as audio_ops
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
SPEECH_DATA='speech_data'

# %%
# The audio is all sampled at 16KHz and should all be 1 second in length - so 1 second is 16000 samples
EXPECTED_SAMPLES=16000
# Noise floor to detect if any audio is present
NOISE_FLOOR=0.1
# How many samples should be abover the noise floor?
MINIMUM_VOICE_LENGTH=EXPECTED_SAMPLES/4

# %%
# list of folders we want to process in the speech_data folder
from tensorflow.python.ops import gen_audio_ops as audio_ops
words = [
    'backward',
    'bed',
    'bird',
    'cat',
    'dog',
    'down',
    'eight',
    'five',
    'follow',
    'forward',
    'four',
    'go',
    'happy',
    'house',
    'learn',
    'left',
    'marvin',
    'nine',
    'no',
    'off',
    'on',
    'one',
    'right',
    'seven',
    'sheila',
    'six',
    'stop',
    'three',
    'tree',
    'two',
    'up',
    'visual',
    'wow',
    'yes',
    'zero',
    '_background',
]

# %%
# get all the files in a directory
def get_files(word):
    return gfile.glob(SPEECH_DATA + '/'+word+'/*.wav')

# get the location of the voice
def get_voice_position(audio, noise_floor):
    audio = audio - np.mean(audio)
    audio = audio / np.max(np.abs(audio))
    return tfio.experimental.audio.trim(audio, axis=0, epsilon=noise_floor)

# Work out how much of the audio file is actually voice
def get_voice_length(audio, noise_floor):
    position = get_voice_position(audio, noise_floor)
    return (position[1] - position[0]).numpy()

# is enough voice present?
def is_voice_present(audio, noise_floor, required_length):
    voice_length = get_voice_length(audio, noise_floor)
    return voice_length >= required_length

# is the audio the correct length?
def is_correct_length(audio, expected_length):
    return (audio.shape[0]==expected_length).numpy()


def is_valid_file(file_name):
    # load the audio file
    audio_tensor = tfio.audio.AudioIOTensor(file_name)
    # check the file is long enough
    if not is_correct_length(audio_tensor, EXPECTED_SAMPLES):
        return False
    # convert the audio to an array of floats and scale it to betweem -1 and 1
    audio = tf.cast(audio_tensor[:], tf.float32)
    audio = audio - np.mean(audio)
    audio = audio / np.max(np.abs(audio))
    # is there any voice in the audio?
    if not is_voice_present(audio, NOISE_FLOOR, MINIMUM_VOICE_LENGTH):
        return False
    return True

# %%
def get_spectrogram(audio):
    # normalise the audio
    audio = audio - np.mean(audio)
    audio = audio / np.max(np.abs(audio))
    # create the spectrogram
    spectrogram = audio_ops.audio_spectrogram(audio,
                                              window_size=320,
                                              stride=160,
                                              magnitude_squared=True).numpy()
    # reduce the number of frequency bins in our spectrogram to a more sensible level
    spectrogram = tf.nn.pool(
        input=tf.expand_dims(spectrogram, -1),
        window_shape=[1, 6],
        strides=[1, 6],
        pooling_type='AVG',
        padding='SAME')
    spectrogram = tf.squeeze(spectrogram, axis=0)
    spectrogram = np.log10(spectrogram + 1e-6)
    return spectrogram

# %%
# process a file into its spectrogram
def process_file(file_path):
    # load the audio file
    audio_tensor = tfio.audio.AudioIOTensor(file_path)
    # convert the audio to an array of floats and scale it to betweem -1 and 1
    audio = tf.cast(audio_tensor[:], tf.float32)
    audio = audio - np.mean(audio)
    audio = audio / np.max(np.abs(audio))
    # randomly reposition the audio in the sample
    voice_start, voice_end = get_voice_position(audio, NOISE_FLOOR)
    end_gap=len(audio) - voice_end
    random_offset = np.random.uniform(0, voice_start+end_gap)
    audio = np.roll(audio,-random_offset+end_gap)
    # add some random background noise
    background_volume = np.random.uniform(0, 0.1)
    # get the background noise files
    background_files = get_files('_background_noise_')
    background_file = np.random.choice(background_files)
    background_tensor = tfio.audio.AudioIOTensor(background_file)
    background_start = np.random.randint(0, len(background_tensor) - 16000)
    # normalise the background noise
    background = tf.cast(background_tensor[background_start:background_start+16000], tf.float32)
    background = background - np.mean(background)
    background = background / np.max(np.abs(background))
    # mix the audio with the scaled background
    audio = audio + background_volume * background
    # get the spectrogram
    return get_spectrogram(audio)

# %%
train = []
validate = []
test = []

TRAIN_SIZE=0.8
VALIDATION_SIZE=0.1
TEST_SIZE=0.1

# %%
def process_files(file_names, label, repeat=1):
    file_names = tf.repeat(file_names, repeat).numpy()
    return [(process_file(file_name), label) for file_name in tqdm(file_names, desc=f"{word} ({label})", leave=False)]

# process the files for a word into the spectrogram and one hot encoding word value
def process_word(word, repeat=1):
    # the index of the word word we are processing
    label = words.index(word)
    # get a list of files names for the word
    file_names = [file_name for file_name in tqdm(get_files(word), desc="Checking", leave=False) if is_valid_file(file_name)]
    # randomly shuffle the filenames
    np.random.shuffle(file_names)
    # split the files into train, validate and test buckets
    train_size=int(TRAIN_SIZE*len(file_names))
    validation_size=int(VALIDATION_SIZE*len(file_names))
    test_size=int(TEST_SIZE*len(file_names))
    # get the training samples
    train.extend(
        process_files(
            file_names[:train_size],
            label,
            repeat=repeat
        )
    )
    # and the validation samples
    validate.extend(
        process_files(
            file_names[train_size:train_size+validation_size],
            label,
            repeat=repeat
        )
    )
    # and the test samples
    test.extend(
        process_files(
            file_names[train_size+validation_size:],
            label,
            repeat=repeat
        )
    )

# process all the words and all the files
for word in tqdm(words, desc="Processing words"):
    if '_' not in word:
        # add more examples of marvin to balance our training set
        repeat = 70 if word == 'marvin' else 1
        process_word(word, repeat=repeat)
    
print(len(train), len(test), len(validate))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Processing words', max=36.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1664.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='backward (0)', max=1225.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='backward (0)', max=153.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='backward (0)', max=154.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2014.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='bed (1)', max=998.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='bed (1)', max=124.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='bed (1)', max=126.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2064.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='bird (2)', max=1293.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='bird (2)', max=161.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='bird (2)', max=163.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2031.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='cat (3)', max=921.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='cat (3)', max=115.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='cat (3)', max=116.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2128.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='dog (4)', max=1306.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='dog (4)', max=163.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='dog (4)', max=164.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3917.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='down (5)', max=2623.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='down (5)', max=327.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='down (5)', max=329.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3787.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='eight (6)', max=1858.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='eight (6)', max=232.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='eight (6)', max=233.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=4052.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='five (7)', max=2376.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='five (7)', max=297.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='five (7)', max=297.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1579.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='follow (8)', max=1063.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='follow (8)', max=132.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='follow (8)', max=134.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1557.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='forward (9)', max=1113.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='forward (9)', max=139.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='forward (9)', max=140.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3728.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='four (10)', max=2250.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='four (10)', max=281.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='four (10)', max=282.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3880.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='go (11)', max=2157.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='go (11)', max=269.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='go (11)', max=271.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2054.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='happy (12)', max=1285.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='happy (12)', max=160.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='happy (12)', max=162.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2113.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='house (13)', max=1132.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='house (13)', max=141.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='house (13)', max=142.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1575.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='learn (14)', max=1096.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='learn (14)', max=137.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='learn (14)', max=137.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3801.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='left (15)', max=1876.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='left (15)', max=234.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='left (15)', max=235.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2100.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='marvin (16)', max=100660.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='marvin (16)', max=12530.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='marvin (16)', max=12670.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3934.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='nine (17)', max=2758.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='nine (17)', max=344.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='nine (17)', max=346.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3941.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='no (18)', max=2464.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='no (18)', max=308.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='no (18)', max=309.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3745.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='off (19)', max=1188.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='off (19)', max=148.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='off (19)', max=150.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3845.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='on (20)', max=2390.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='on (20)', max=298.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='on (20)', max=300.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3890.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='one (21)', max=2324.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='one (21)', max=290.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='one (21)', max=292.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3778.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='right (22)', max=2111.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='right (22)', max=263.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='right (22)', max=265.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3998.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='seven (23)', max=2753.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='seven (23)', max=344.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='seven (23)', max=345.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2022.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='sheila (24)', max=1384.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='sheila (24)', max=173.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='sheila (24)', max=173.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3860.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='six (25)', max=2321.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='six (25)', max=290.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='six (25)', max=291.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3872.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='stop (26)', max=2001.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='stop (26)', max=250.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='stop (26)', max=251.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3727.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='three (27)', max=2276.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='three (27)', max=284.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='three (27)', max=286.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1759.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='tree (28)', max=1118.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='tree (28)', max=139.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='tree (28)', max=141.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3880.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='two (29)', max=2164.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='two (29)', max=270.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='two (29)', max=271.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=3723.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='up (30)', max=790.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='up (30)', max=98.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='up (30)', style=ProgressStyle(description_width='initial'…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=1592.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='visual (31)', max=1149.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='visual (31)', max=143.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='visual (31)', max=145.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=2123.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='wow (32)', max=1356.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='wow (32)', max=169.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='wow (32)', max=170.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=4044.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='yes (33)', max=2364.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='yes (33)', max=295.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='yes (33)', max=297.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Checking', max=4052.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='zero (34)', max=2957.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='zero (34)', max=369.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='zero (34)', max=371.0, style=ProgressStyle(description_wi…
# 161100 20258 20070

# %%
# process the background noise files
def process_background(file_name, label):
    # load the audio file
    audio_tensor = tfio.audio.AudioIOTensor(file_name)
    audio = tf.cast(audio_tensor[:], tf.float32)
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(range(0, audio_length-EXPECTED_SAMPLES, 8000), desc=file_name, leave=False):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end]
        # get the spectrogram
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))

    # simulate random utterances
    for section_index in tqdm(range(1000), desc="Simulated Words", leave=False):
        section_start = np.random.randint(0, audio_length - EXPECTED_SAMPLES)
        section_end = section_start + EXPECTED_SAMPLES
        section = np.reshape(audio[section_start:section_end], (EXPECTED_SAMPLES))

        result = np.zeros((EXPECTED_SAMPLES))
        # create a pseudo bit of voice
        voice_length = np.random.randint(MINIMUM_VOICE_LENGTH/2, EXPECTED_SAMPLES)
        voice_start = np.random.randint(0, EXPECTED_SAMPLES - voice_length)
        hamming = np.hamming(voice_length)
        # amplify the voice section
        result[voice_start:voice_start+voice_length] = hamming * section[voice_start:voice_start+voice_length]
        # get the spectrogram
        spectrogram = get_spectrogram(np.reshape(section, (16000, 1)))
        samples.append((spectrogram, label))
        
    
    np.random.shuffle(samples)
    
    train_size=int(TRAIN_SIZE*len(samples))
    validation_size=int(VALIDATION_SIZE*len(samples))
    test_size=int(TEST_SIZE*len(samples))
    
    train.extend(samples[:train_size])

    validate.extend(samples[train_size:train_size+validation_size])

    test.extend(samples[train_size+validation_size:])

        
for file_name in tqdm(get_files('_background_noise_'), desc="Processing Background Noise"):
    process_background(file_name, words.index("_background"))
    
print(len(train), len(test), len(validate))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Processing Background Noise', max=11.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/pink_noise.wav', max=118.0…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/white_noise.wav', max=118.…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/background.wav', max=965.0…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/background5.wav', max=6185…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/background4.wav', max=1440…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/background3.wav', max=2398…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/background2.wav', max=32.0…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/dude_miaowing.wav', max=12…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/doing_the_dishes.wav', max…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/exercise_bike.wav', max=12…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_background_noise_/running_tap.wav', max=121.…
# HBox(children=(FloatProgress(value=0.0, description='Simulated Words', max=1000.0, style=ProgressStyle(descrip…
# 189711 23845 23642

# %%
def process_problem_noise(file_name, label):
    samples = []
    # load the audio file
    audio_tensor = tfio.audio.AudioIOTensor(file_name)
    audio = tf.cast(audio_tensor[:], tf.float32)
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(range(0, audio_length-EXPECTED_SAMPLES, 400), desc=file_name, leave=False):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end]
        # get the spectrogram
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))
        
    np.random.shuffle(samples)
    
    train_size=int(TRAIN_SIZE*len(samples))
    validation_size=int(VALIDATION_SIZE*len(samples))
    test_size=int(TEST_SIZE*len(samples))
    
    train.extend(samples[:train_size])
    validate.extend(samples[train_size:train_size+validation_size])
    test.extend(samples[train_size+validation_size:])


for file_name in tqdm(get_files("_problem_noise_"), desc="Processing problem noise"):
    process_problem_noise(file_name, words.index("_background"))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Processing problem noise', max=5.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_problem_noise_/noise4.wav', max=1240.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_problem_noise_/noise5.wav', max=1240.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_problem_noise_/noise2.wav', max=1240.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_problem_noise_/noise3.wav', max=1240.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_problem_noise_/noise.wav', max=4853.0, style…

# %%
def process_mar_sounds(file_name, label):
    samples = []
    # load the audio file
    audio_tensor = tfio.audio.AudioIOTensor(file_name)
    audio = tf.cast(audio_tensor[:], tf.float32)
    audio_length = len(audio)
    samples = []
    for section_start in tqdm(range(0, audio_length-EXPECTED_SAMPLES, 4000), desc=file_name, leave=False):
        section_end = section_start + EXPECTED_SAMPLES
        section = audio[section_start:section_end]
        section = section - np.mean(section)
        section = section / np.max(np.abs(section))
        # add some random background noise
        background_volume = np.random.uniform(0, 0.1)
        # get the background noise files
        background_files = get_files('_background_noise_')
        background_file = np.random.choice(background_files)
        background_tensor = tfio.audio.AudioIOTensor(background_file)
        background_start = np.random.randint(0, len(background_tensor) - 16000)
        # normalise the background noise
        background = tf.cast(background_tensor[background_start:background_start+16000], tf.float32)
        background = background - np.mean(background)
        background = background / np.max(np.abs(background))
        # mix the audio with the scaled background
        section = section + background_volume * background
        # get the spectrogram
        spectrogram = get_spectrogram(section)
        samples.append((spectrogram, label))
        
    np.random.shuffle(samples)
    
    train_size=int(TRAIN_SIZE*len(samples))
    validation_size=int(VALIDATION_SIZE*len(samples))
    test_size=int(TEST_SIZE*len(samples))
    
    train.extend(samples[:train_size])
    validate.extend(samples[train_size:train_size+validation_size])
    test.extend(samples[train_size+validation_size:])


for file_name in tqdm(get_files("_mar_sounds_"), desc="Processing problem noise"):
    process_mar_sounds(file_name, words.index("_background"))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Processing problem noise', max=1.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='speech_data/_mar_sounds_/mar_sounds_from_say.wav', max=18…

# %%
print(len(train), len(test), len(validate))
# Out:
# 212645 26713 26508

# %%
# randomise the training samples
np.random.shuffle(train)

# %%
X_train, Y_train = zip(*train)
X_validate, Y_validate = zip(*validate)
X_test, Y_test = zip(*test)

# %%
# save the computed data
np.savez_compressed(
    "training_spectrogram.npz",
    X=X_train, Y=Y_train)
print("Saved training data")
np.savez_compressed(
    "validation_spectrogram.npz",
    X=X_validate, Y=Y_validate)
print("Saved validation data")
np.savez_compressed(
    "test_spectrogram.npz",
    X=X_test, Y=Y_test)
print("Saved test data")
# Out:
# Saved training data
# Saved validation data
# Saved test data

# %%
# get the width and height of the spectrogram "image"
IMG_WIDTH=X_train[0].shape[0]
IMG_HEIGHT=X_train[0].shape[1]

# %%
def plot_images2(images_arr, imageWidth, imageHeight):
    fig, axes = plt.subplots(5, 5, figsize=(10, 20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(np.reshape(img, (imageWidth, imageHeight)))
        ax.axis("off")
    plt.tight_layout()
    plt.show()

# %%
word_index = words.index("marvin")

X_marvins = np.array(X_train)[np.array(Y_train) == word_index]
Y_marvins = np.array(Y_train)[np.array(Y_train) == word_index]
plot_images2(X_marvins[:20], IMG_WIDTH, IMG_HEIGHT)
print(Y_marvins[:20])
# Out:
# [16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16 16]

# %%
word_index = words.index("yes")

X_yes = np.array(X_train)[np.array(Y_train) == word_index]
Y_yes = np.array(Y_train)[np.array(Y_train) == word_index]
plot_images2(X_yes[:20], IMG_WIDTH, IMG_HEIGHT)
print(Y_yes[:20])
# Out:
# [33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33 33]
